# %% [markdown]
# # AppService (WordPress)

# %% [markdown]
# Primero buscamos WordPress y creamos un recurso de esto
# ![image.png](attachment:66914bca-aa15-4c1a-8f30-29900e31b58f.png)
# ![image.png](attachment:fb0ea9f1-506c-47e9-b8c0-19e2e4a3cb59.png)

# %% [markdown]
# Agregamos las Etiquetas
# ![image.png](attachment:f78975e4-7b00-4c24-bb96-8ade4e25c842.png)

# %% [markdown]
# Creamos y nos dirigimos al URL que marca en lab03-dr
# ![image.png](attachment:f6afbd2c-0504-4aa0-ad90-d90566cb54ce.png)

# %% [markdown]
# Y asi quedaría nuestra pagina web en WordPress:
# ![image.png](attachment:dd6b75a4-7a8b-422a-9856-8f3999e86ba1.png)

# %% [markdown]
# Lo editamos a nuestro gusto
# ![image.png](attachment:6d764fc9-90c5-4e16-b4b7-be570f99aa55.png)
